# %%
print('hello')
# Out:
# hello

# %% [markdown]
# ## Testing which recoruces we are being used

# %%
import sys
print("Python executable:", sys.executable)
print("Python version:", sys.version)
print("Python path:", sys.path[:3])
# Out:
# Python executable: c:\Users\amare\Desktop\HouseRental\venv\Scripts\python.exe
# Python version: 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]
# Python path: ['C:\\Program Files\\Python313\\python313.zip', 'C:\\Program Files\\Python313\\DLLs', 'C:\\Program Files\\Python313\\Lib']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

print("All packages imported successfully! ✅")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# All packages imported successfully! ✅
# Pandas version: 2.3.3
# NumPy version: 2.3.4

# %%
import subprocess
import sys

result = subprocess.run([sys.executable, '-m', 'pip', 'list'], capture_output=True, text=True)
print(result.stdout)
# Out:
# Package                   Version
# ------------------------- -----------
# altair                    5.5.0
# asttokens                 3.0.0
# attrs                     25.4.0
# blinker                   1.9.0
# cachetools                6.2.1
# certifi                   2025.10.5
# charset-normalizer        3.4.4
# click                     8.3.0
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.17
# decorator                 5.2.1
# executing                 2.2.1
# fonttools                 4.60.1
# gitdb                     4.0.12
# GitPython                 3.1.45
# idna                      3.11
# ipykernel                 7.1.0
# ipython                   9.7.0
# ipython_pygments_lexers   1.1.1
# jedi                      0.19.2
# Jinja2                    3.1.6
# joblib                    1.5.2
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter_client            8.6.3
# jupyter_core              5.9.1
# kiwisolver                1.4.9
# MarkupSafe                3.0.3
# matplotlib                3.10.7
# matplotlib-inline         0.2.1
# missingno                 0.5.2
# narwhals                  2.10.2
# nest-asyncio              1.6.0
# numpy                     2.3.4
# packaging                 25.0
# pandas                    2.3.3
# parso                     0.8.5
# pillow                    12.0.0
# pip                       24.3.1
# pipeline                  0.1.0
# platformdirs              4.5.0
# prompt_toolkit            3.0.52
# protobuf                  6.33.0
# psutil                    7.1.3
# pure_eval                 0.2.3
# pyarrow                   21.0.0
# pydeck                    0.9.1
# Pygments                  2.19.2
# pyparsing                 3.2.5
# python-dateutil           2.9.0.post0
# pytz                      2025.2
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# rpds-py                   0.28.0
# scikit-learn              1.7.2
# scipy                     1.16.3
# seaborn                   0.13.2
# six                       1.17.0
# smmap                     5.0.2
# stack-data                0.6.3
# streamlit                 1.51.0
# tenacity                  9.1.2
# threadpoolctl             3.6.0
# toml                      0.10.2
# tornado                   6.5.2
# traitlets                 5.14.3
# typing_extensions         4.15.0
# tzdata                    2025.2
# urllib3                   2.5.0
# watchdog                  6.0.0
# wcwidth                   0.2.14
# xgboost                   3.1.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import joblib
from sklearn.pipeline import Pipeline
# Load the saved model

print("All packages imported successfully! ✅")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# All packages imported successfully! ✅
# Pandas version: 2.3.3
# NumPy version: 2.3.4

# %%
df=pd.read_csv('C:\\Users\\amare\\Desktop\\HouseRental\\data\\House Rental.csv')
# Out:
# C:\Users\amare\AppData\Local\Temp\ipykernel_23212\1872732403.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('C:\\Users\\amare\\Desktop\\HouseRental\\data\\House Rental.csv')

# %%
df.head()
# Out:
#    listing_id        listing_category                         headline  \
# 0  5668640009  housing/rent/apartment       One BR 507 & 509 Esplanade
# 1  5668639818  housing/rent/apartment      Three BR 146 Lochview Drive
# 2  5668639686  housing/rent/apartment  Three BR 3101 Morningside Drive
# 3  5668639659  housing/rent/apartment            Two BR 209 Aegean Way
# 4  5668639374  housing/rent/apartment         One BR 4805 Marquette NE
#
#                                          description included_features  \
# 0  This unit is located at 507 & 509 Esplanade, R...               NaN
# 1  This unit is located at 146 Lochview Drive, Ne...               NaN
# 2  This unit is located at 3101 Morningside Drive...               NaN
# 3  This unit is located at 209 Aegean Way, Vacavi...               NaN
# 4  This unit is located at 4805 Marquette NE, Alb...               NaN
#
#    bath_count  bed_count payment_currency service_fee_applicable  \
# 0         1.0        1.0              USD                     No
# 1         1.5        3.0              USD                     No
# 2         2.0        3.0              USD                     No
# 3         1.0        2.0              USD                     No
# 4         1.0        1.0              USD                     No
#
#   image_available  ... formatted_rent_text  payment_schedule area_in_sqft  \
# 0       Thumbnail  ...              $2,195           Monthly          542
# 1       Thumbnail  ...              $1,250           Monthly         1500
# 2       Thumbnail  ...              $1,395           Monthly         1650
# 3       Thumbnail  ...              $1,600           Monthly          820
# 4       Thumbnail  ...                $975           Monthly          624
#
#         street_address           city region_code  geo_lat   geo_lon  \
# 0   507  509 Esplanade  Redondo Beach          CA  33.8520 -118.3759
# 1      146 Lochview Dr   Newport News          VA  37.0867  -76.4941
# 2  3101 Morningside Dr        Raleigh          NC  35.8230  -78.6438
# 3       209 Aegean Way      Vacaville          CA  38.3622 -121.9712
# 4    4805 Marquette NE    Albuquerque          NM  35.1038 -106.6110
#
#    data_provider  listing_timestamp
# 0      RentLingo         1577360355
# 1      RentLingo         1577360340
# 2      RentLingo         1577360332
# 3      RentLingo         1577360330
# 4      RentLingo         1577360308
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['listing_id', 'listing_category', 'headline', 'description',
#        'included_features', 'bath_count', 'bed_count', 'payment_currency',
#        'service_fee_applicable', 'image_available', 'pet_policy',
#        'monthly_rent', 'formatted_rent_text', 'payment_schedule',
#        'area_in_sqft', 'street_address', 'city', 'region_code', 'geo_lat',
#        'geo_lon', 'data_provider', 'listing_timestamp'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   listing_id              99492 non-null  int64
#  1   listing_category        99492 non-null  object
#  2   headline                99492 non-null  object
#  3   description             99489 non-null  object
#  4   included_features       83448 non-null  object
#  5   bath_count              99429 non-null  float64
#  6   bed_count               99368 non-null  float64
#  7   payment_currency        99492 non-null  object
#  8   service_fee_applicable  99492 non-null  object
#  9   image_available         99492 non-null  object
#  10  pet_policy              39068 non-null  object
#  11  monthly_rent            99491 non-null  float64
#  12  formatted_rent_text     99491 non-null  object
#  13  payment_schedule        99492 non-null  object
#  14  area_in_sqft            99492 non-null  int64
#  15  street_address          7943 non-null   object
#  16  city                    99190 non-null  object
#  17  region_code             99190 non-null  object
#  18  geo_lat                 99467 non-null  float64
#  19  geo_lon                 99467 non-null  float64
#  20  data_provider           99492 non-null  object
#  21  listing_timestamp       99492 non-null  int64
# dtypes: float64(5), int64(3), object(14)
# memory usage: 16.7+ MB
